# %%
# this is the testing document

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import tensorflow as tf
from stn import spatial_transformer_network as transformer
import tensorflow.keras.activations as ac
import numpy as np
import matplotlib.pyplot as plt
import os
#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import cv2

# %%
train = ImageDataGenerator(rescale=1 / 255,validation_split=0.17)
test = ImageDataGenerator(rescale=1 / 255)

# %%
image_size=(150,150)

# %%
train_dataset = train.flow_from_directory("../database/sharpness1/train",
                                          target_size=image_size,
                                          class_mode="categorical",
                                          subset="training",
                                          
                                         )
valid_dataset = train.flow_from_directory("../database/sharpness1/train",
                                          target_size=image_size,
                                          class_mode="categorical",                                          
                                          subset="validation")

test_dataset = test.flow_from_directory("../database/sharpness1/test",
                                        target_size=image_size,                                       
                                        class_mode="categorical")
# Out:
# Found 3446 images belonging to 58 classes.
# Found 666 images belonging to 58 classes.
# Found 1940 images belonging to 58 classes.

# %%
model = tf.keras.models.Sequential(
    [
        tf.keras.Input(shape=(150, 150, 3)),
        
        
        tf.keras.layers.Conv2D(96, strides=(11,11),kernel_size=(11, 11),padding="valid",activation="relu"),
        tf.keras.layers.MaxPooling2D(pool_size=(2 ,2),strides=(2,2)),
        
        
        tf.keras.layers.Conv2D(256,strides=(1,1), kernel_size=(5, 5), padding="same",activation="relu"),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=(2,2)),
        
        tf.keras.layers.Conv2D(384, kernel_size=(3, 3),padding="same",activation="relu"),
        tf.keras.layers.Conv2D(384, kernel_size=(3, 3),padding="same",activation="relu"),
        tf.keras.layers.Conv2D(256, kernel_size=(3, 3),padding="same",activation="relu"),
        tf.keras.layers.MaxPooling2D(pool_size=(3, 3)),
      

        tf.keras.layers.Flatten(),

        tf.keras.layers.Dense(4096,activation="relu"),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(4096,activation="relu"),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(1024,activation="relu"),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(58, activation="softmax")
    ]
)
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_32 (Conv2D)           (None, 13, 13, 96)        34944
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 6, 6, 96)          0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 6, 6, 256)         614656
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 3, 3, 256)         0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 3, 3, 384)         885120
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 3, 3, 384)         1327488
# _________________________________________________________________
# ...

# %%
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(train_dataset, steps_per_epoch=50,validation_data=valid_dataset, epochs=100)

score = model.evaluate(test_dataset, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
print("hello this is the end ***")
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 50 steps, validate for 21 steps
# Epoch 1/100
# 50/50 [==============================] - 2s 50ms/step - loss: 3.7613 - accuracy: 0.0818 - val_loss: 3.4947 - val_accuracy: 0.1126
# Epoch 2/100
# 50/50 [==============================] - 2s 38ms/step - loss: 3.5500 - accuracy: 0.0988 - val_loss: 3.4910 - val_accuracy: 0.1126
# Epoch 3/100
# 50/50 [==============================] - 2s 38ms/step - loss: 3.5343 - accuracy: 0.0981 - val_loss: 3.3154 - val_accuracy: 0.0811
# Epoch 4/100
# 50/50 [==============================] - 2s 38ms/step - loss: 3.2163 - accuracy: 0.1396 - val_loss: 2.9190 - val_accuracy: 0.1787
# Epoch 5/100
# 50/50 [==============================] - 2s 38ms/step - loss: 2.9322 - accuracy: 0.1644 - val_loss: 2.6716 - val_accuracy: 0.2057
# Epoch 6/100
# ...
