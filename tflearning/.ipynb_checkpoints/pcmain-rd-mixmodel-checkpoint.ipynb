# %%
# this is the reduceddatabase
# mix model of Alexnet and

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import tensorflow as tf
from stn import spatial_transformer_network as transformer
from tensorflow.keras.regularizers import l2
import tensorflow.keras.activations as ac
import numpy as np
import matplotlib.pyplot as plt
import os
#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import cv2

# %%
train = ImageDataGenerator(rescale=1 / 255,validation_split=0.2)
test = ImageDataGenerator(rescale=1 / 255)

# %%
image_size=(150,150)

# %%
train_dataset = train.flow_from_directory("../database/sharpness1reduce/train",
                                          target_size=image_size,
                                          class_mode="categorical",
                                          subset="training",
                                          
                                         )
valid_dataset = train.flow_from_directory("../database/sharpness1reduce/train",
                                          target_size=image_size,
                                          class_mode="categorical",                                          
                                          subset="validation")

test_dataset = test.flow_from_directory("../database/sharpness1reduce/test",
                                        target_size=image_size,                                       
                                        class_mode="categorical")
# Out:
# Found 3282 images belonging to 49 classes.
# Found 795 images belonging to 49 classes.
# Found 1919 images belonging to 49 classes.

# %%
model = tf.keras.models.Sequential()
    
model.add(tf.keras.Input(shape=(150, 150, 3)))
model.add(tf.keras.layers.Conv2D(32,(7, 7),padding="same",activation="relu"))       
model.add(tf.keras.layers.Conv2D(64,(3, 3),activation="relu"))

model.add(tf.keras.layers.MaxPooling2D(pool_size=(2 ,2)))
        
model.add(tf.keras.layers.Conv2D(64,(3, 3), padding="same",activation="relu"))
model.add(tf.keras.layers.Conv2D(64,(3, 3), padding="same",activation="relu"))
model.add(tf.keras.layers.Conv2D(64,(3, 3),activation="relu"))

model.add(tf.keras.layers.MaxPooling2D(pool_size=(2 ,2)))

        
model.add(tf.keras.layers.Conv2D(32,(3, 3),padding="same",activation="relu"))     
model.add(tf.keras.layers.Conv2D(64,(3, 3),activation="relu"))

model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    

model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(1024,kernel_regularizer=l2(0.005),bias_regularizer=l2(0.005)))
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.BatchNormalization()),
model.add(tf.keras.layers.Dropout(0.5))

model.add(tf.keras.layers.Dense(512,kernel_regularizer=l2(0.005),bias_regularizer=l2(0.005)))
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.5))
        
model.add(tf.keras.layers.Dense(256,kernel_regularizer=l2(0.005),bias_regularizer=l2(0.005)))
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.5))
        
model.add(tf.keras.layers.Dense(128))
model.add(tf.keras.layers.ReLU())
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(49, activation="softmax"))
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_39 (Conv2D)           (None, 150, 150, 32)      4736
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 148, 148, 64)      18496
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 74, 74, 64)        0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 74, 74, 64)        36928
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 74, 74, 64)        36928
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 72, 72, 64)        36928
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 36, 36, 32)        18464
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_25 (Dense)             (None, 1024)              18940928
# _________________________________________________________________
# re_lu_16 (ReLU)              (None, 1024)              0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 1024)              4096
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_26 (Dense)             (None, 512)               524800
# _________________________________________________________________
# re_lu_17 (ReLU)              (None, 512)               0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 256)               131328
# _________________________________________________________________
# re_lu_18 (ReLU)              (None, 256)               0
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 128)               32896
# _________________________________________________________________
# re_lu_19 (ReLU)              (None, 128)               0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_29 (Dense)             (None, 49)                6321
# =================================================================
# Total params: 19,814,929
# Trainable params: 19,811,089
# Non-trainable params: 3,840
# _________________________________________________________________

# %%
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.fit(train_dataset, steps_per_epoch=50,validation_data=valid_dataset, epochs=50,shuffle=True)


score = model.evaluate(test_dataset, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
print("hello this is the end ***")
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 50 steps, validate for 25 steps
# Epoch 1/50
# 50/50 [==============================] - 5s 103ms/step - loss: 15.9446 - accuracy: 0.0580 - val_loss: 52.0783 - val_accuracy: 0.1119
# Epoch 2/50
# 50/50 [==============================] - 4s 74ms/step - loss: 12.5202 - accuracy: 0.1583 - val_loss: 16.0530 - val_accuracy: 0.1107
# Epoch 3/50
# 50/50 [==============================] - 4s 74ms/step - loss: 10.3835 - accuracy: 0.2528 - val_loss: 11.0439 - val_accuracy: 0.1447
# Epoch 4/50
# 50/50 [==============================] - 4s 74ms/step - loss: 9.0052 - accuracy: 0.3764 - val_loss: 12.9485 - val_accuracy: 0.1145
# Epoch 5/50
# 50/50 [==============================] - 4s 75ms/step - loss: 7.8509 - accuracy: 0.4288 - val_loss: 11.0921 - val_accuracy: 0.1698
# Epoch 6/50
# 50/50 [==============================] - 4s 75ms/step - loss: 6.9081 - accuracy: 0.5175 - val_loss: 8.4442 - val_accuracy: 0.2428
# Epoch 7/50
# 50/50 [==============================] - 4s 75ms/step - loss: 6.4310 - accuracy: 0.5460 - val_loss: 5.8258 - val_accuracy: 0.6390
# Epoch 8/50
# 50/50 [==============================] - 4s 75ms/step - loss: 5.6665 - accuracy: 0.6044 - val_loss: 5.4775 - val_accuracy: 0.5547
# Epoch 9/50
# 50/50 [==============================] - 4s 74ms/step - loss: 4.9365 - accuracy: 0.6564 - val_loss: 5.2714 - val_accuracy: 0.5308
# Epoch 10/50
# 50/50 [==============================] - 4s 74ms/step - loss: 4.5175 - accuracy: 0.6873 - val_loss: 4.7121 - val_accuracy: 0.5585
# Epoch 11/50
# 50/50 [==============================] - 4s 74ms/step - loss: 4.2217 - accuracy: 0.7024 - val_loss: 4.2387 - val_accuracy: 0.7006
# Epoch 12/50
# 50/50 [==============================] - 4s 74ms/step - loss: 3.9382 - accuracy: 0.7207 - val_loss: 3.9447 - val_accuracy: 0.6704
# Epoch 13/50
# 50/50 [==============================] - 4s 75ms/step - loss: 3.5950 - accuracy: 0.7581 - val_loss: 3.2890 - val_accuracy: 0.8428
# Epoch 14/50
# 50/50 [==============================] - 4s 75ms/step - loss: 3.3784 - accuracy: 0.7856 - val_loss: 3.3982 - val_accuracy: 0.7824
# Epoch 15/50
# 50/50 [==============================] - 4s 74ms/step - loss: 3.2364 - accuracy: 0.7912 - val_loss: 3.3982 - val_accuracy: 0.7447
# Epoch 16/50
# 50/50 [==============================] - 4s 74ms/step - loss: 3.0912 - accuracy: 0.8052 - val_loss: 3.0491 - val_accuracy: 0.8591
# Epoch 17/50
# 50/50 [==============================] - 4s 74ms/step - loss: 2.9288 - accuracy: 0.8121 - val_loss: 2.7273 - val_accuracy: 0.8629
# Epoch 18/50
# 50/50 [==============================] - 4s 74ms/step - loss: 2.7210 - accuracy: 0.8291 - val_loss: 2.6061 - val_accuracy: 0.8755
# Epoch 19/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.6288 - accuracy: 0.8425 - val_loss: 2.5061 - val_accuracy: 0.8679
# Epoch 20/50
# 50/50 [==============================] - 4s 74ms/step - loss: 2.6441 - accuracy: 0.8354 - val_loss: 2.5868 - val_accuracy: 0.8730
# Epoch 21/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.6714 - accuracy: 0.8562 - val_loss: 2.5188 - val_accuracy: 0.9006
# Epoch 22/50
# 50/50 [==============================] - 4s 74ms/step - loss: 2.6414 - accuracy: 0.8726 - val_loss: 2.4761 - val_accuracy: 0.8981
# Epoch 23/50
# 50/50 [==============================] - 4s 74ms/step - loss: 2.4645 - accuracy: 0.8808 - val_loss: 2.2385 - val_accuracy: 0.9409
# Epoch 24/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.3475 - accuracy: 0.8808 - val_loss: 2.1345 - val_accuracy: 0.9283
# Epoch 25/50
# 50/50 [==============================] - 4s 74ms/step - loss: 2.2885 - accuracy: 0.8838 - val_loss: 2.0876 - val_accuracy: 0.9384
# Epoch 26/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.2125 - accuracy: 0.8988 - val_loss: 2.0401 - val_accuracy: 0.9547
# Epoch 27/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.2607 - accuracy: 0.8950 - val_loss: 2.4057 - val_accuracy: 0.8604
# Epoch 28/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.4360 - accuracy: 0.8888 - val_loss: 2.3644 - val_accuracy: 0.9094
# Epoch 29/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.2810 - accuracy: 0.9111 - val_loss: 2.1185 - val_accuracy: 0.9270
# Epoch 30/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.2110 - accuracy: 0.8972 - val_loss: 1.9938 - val_accuracy: 0.9610
# Epoch 31/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.1969 - accuracy: 0.9062 - val_loss: 2.0637 - val_accuracy: 0.9686
# Epoch 32/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.2604 - accuracy: 0.9162 - val_loss: 2.1422 - val_accuracy: 0.9296
# Epoch 33/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.2690 - accuracy: 0.9004 - val_loss: 2.1174 - val_accuracy: 0.9459
# Epoch 34/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.2768 - accuracy: 0.9200 - val_loss: 2.2408 - val_accuracy: 0.9409
# Epoch 35/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.1854 - accuracy: 0.9250 - val_loss: 2.2275 - val_accuracy: 0.9170
# Epoch 36/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.3062 - accuracy: 0.9199 - val_loss: 2.3436 - val_accuracy: 0.9409
# Epoch 37/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.4450 - accuracy: 0.9054 - val_loss: 2.2824 - val_accuracy: 0.9509
# Epoch 38/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.3440 - accuracy: 0.9288 - val_loss: 2.1919 - val_accuracy: 0.9572
# Epoch 39/50
# 50/50 [==============================] - 4s 76ms/step - loss: 2.1908 - accuracy: 0.9381 - val_loss: 1.9647 - val_accuracy: 0.9748
# Epoch 40/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.1563 - accuracy: 0.9275 - val_loss: 2.0461 - val_accuracy: 0.9774
# Epoch 41/50
# 50/50 [==============================] - 4s 74ms/step - loss: 2.1727 - accuracy: 0.9338 - val_loss: 2.0142 - val_accuracy: 0.9711
# Epoch 42/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.0775 - accuracy: 0.9438 - val_loss: 1.9674 - val_accuracy: 0.9711
# Epoch 43/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.2425 - accuracy: 0.9237 - val_loss: 2.1801 - val_accuracy: 0.9774
# Epoch 44/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.3491 - accuracy: 0.9275 - val_loss: 2.2738 - val_accuracy: 0.9635
# Epoch 45/50
# 50/50 [==============================] - 4s 74ms/step - loss: 2.1924 - accuracy: 0.9439 - val_loss: 1.9916 - val_accuracy: 0.9686
# Epoch 46/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.0733 - accuracy: 0.9395 - val_loss: 1.9758 - val_accuracy: 0.9748
# Epoch 47/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.2323 - accuracy: 0.9519 - val_loss: 2.0814 - val_accuracy: 0.9786
# Epoch 48/50
# 50/50 [==============================] - 4s 74ms/step - loss: 2.0823 - accuracy: 0.9433 - val_loss: 1.9701 - val_accuracy: 0.9811
# Epoch 49/50
# 50/50 [==============================] - 4s 75ms/step - loss: 2.1873 - accuracy: 0.9344 - val_loss: 2.2027 - val_accuracy: 0.9761
# Epoch 50/50
# 50/50 [==============================] - 4s 76ms/step - loss: 2.3644 - accuracy: 0.9356 - val_loss: 2.1685 - val_accuracy: 0.9799
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Test loss: 3.0996062397956847
# Test accuracy: 0.761334
# hello this is the end ***
