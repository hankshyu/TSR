# %%
# this is the classic cnn model 70%

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import tensorflow as tf
from stn import spatial_transformer_network as transformer
import tensorflow.keras.activations as ac
import numpy as np
import matplotlib.pyplot as plt
import os
#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import cv2

# %%
train = ImageDataGenerator(rescale=1 / 255,validation_split=0.17)
test = ImageDataGenerator(rescale=1 / 255)

# %%
image_size=(150,150)

# %%
train_dataset = train.flow_from_directory("../database/sharpness1/train",
                                          target_size=image_size,
                                          class_mode="categorical",
                                          subset="training",
                                          
                                         )
valid_dataset = train.flow_from_directory("../database/sharpness1/train",
                                          target_size=image_size,
                                          class_mode="categorical",                                          
                                          subset="validation")

test_dataset = test.flow_from_directory("../database/sharpness1/test",
                                        target_size=image_size,                                       
                                        class_mode="categorical")
# Out:
# Found 3446 images belonging to 58 classes.
# Found 666 images belonging to 58 classes.
# Found 1940 images belonging to 58 classes.

# %%
model = tf.keras.models.Sequential(
    [
        tf.keras.Input(shape=(150, 150, 3)),
        tf.keras.layers.Conv2D(32, kernel_size=(7, 7),padding="same",activation="relu"),
        tf.keras.layers.Conv2D(64, kernel_size=(3, 3),activation="relu"),
        tf.keras.layers.MaxPooling2D(pool_size=(2 ,2)),
        tf.keras.layers.Conv2D(32, kernel_size=(5, 5), padding="same",activation="relu"),
        tf.keras.layers.Conv2D(64, kernel_size=(3, 3),activation="relu"),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Conv2D(32, kernel_size=(3, 3),activation="relu"),
        tf.keras.layers.Conv2D(64, kernel_size=(3, 3),activation="relu"),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
      

        tf.keras.layers.Flatten(),

        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(256),
        tf.keras.layers.LeakyReLU(alpha=0.2),
        tf.keras.layers.Dense(128),
        tf.keras.layers.LeakyReLU(alpha=0.2),
        tf.keras.layers.Dense(58, activation="softmax")
    ]
)
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_64 (Conv2D)           (None, 150, 150, 32)      4736
# _________________________________________________________________
# conv2d_65 (Conv2D)           (None, 148, 148, 64)      18496
# _________________________________________________________________
# max_pooling2d_36 (MaxPooling (None, 74, 74, 64)        0
# _________________________________________________________________
# conv2d_66 (Conv2D)           (None, 74, 74, 32)        51232
# _________________________________________________________________
# conv2d_67 (Conv2D)           (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_37 (MaxPooling (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_68 (Conv2D)           (None, 34, 34, 32)        18464
# _________________________________________________________________
# conv2d_69 (Conv2D)           (None, 32, 32, 64)        18496
# _________________________________________________________________
# conv2d_70 (Conv2D)           (None, 30, 30, 64)        36928
# _________________________________________________________________
# max_pooling2d_38 (MaxPooling (None, 15, 15, 64)        0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 14400)             0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 14400)             0
# _________________________________________________________________
# dense_39 (Dense)             (None, 256)               3686656
# _________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)   (None, 256)               0
# _________________________________________________________________
# dense_40 (Dense)             (None, 128)               32896
# _________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)   (None, 128)               0
# _________________________________________________________________
# dense_41 (Dense)             (None, 58)                7482
# =================================================================
# Total params: 3,893,882
# Trainable params: 3,893,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(train_dataset, steps_per_epoch=50,validation_data=valid_dataset, epochs=40)

score = model.evaluate(test_dataset, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
print("hello this is the end ***")
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 50 steps, validate for 21 steps
# Epoch 1/40
# 50/50 [==============================] - 4s 77ms/step - loss: 3.6680 - accuracy: 0.1200 - val_loss: 3.1048 - val_accuracy: 0.1772
# Epoch 2/40
# 50/50 [==============================] - 3s 60ms/step - loss: 2.6310 - accuracy: 0.3189 - val_loss: 2.3073 - val_accuracy: 0.3934
# Epoch 3/40
# 50/50 [==============================] - 3s 57ms/step - loss: 1.8271 - accuracy: 0.5181 - val_loss: 1.2982 - val_accuracy: 0.6682
# Epoch 4/40
# 50/50 [==============================] - 3s 57ms/step - loss: 1.0054 - accuracy: 0.7145 - val_loss: 0.6751 - val_accuracy: 0.8243
# Epoch 5/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.6417 - accuracy: 0.8238 - val_loss: 0.5356 - val_accuracy: 0.8378
# Epoch 6/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.4165 - accuracy: 0.8786 - val_loss: 0.3480 - val_accuracy: 0.9099
# Epoch 7/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.3104 - accuracy: 0.9244 - val_loss: 0.2580 - val_accuracy: 0.9264
# Epoch 8/40
# 50/50 [==============================] - 3s 58ms/step - loss: 0.1884 - accuracy: 0.9494 - val_loss: 0.2643 - val_accuracy: 0.9324
# Epoch 9/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.1785 - accuracy: 0.9528 - val_loss: 0.2100 - val_accuracy: 0.9294
# Epoch 10/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.1188 - accuracy: 0.9635 - val_loss: 0.2029 - val_accuracy: 0.9339
# Epoch 11/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0951 - accuracy: 0.9694 - val_loss: 0.1022 - val_accuracy: 0.9760
# Epoch 12/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0825 - accuracy: 0.9725 - val_loss: 0.0727 - val_accuracy: 0.9850
# Epoch 13/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0721 - accuracy: 0.9830 - val_loss: 0.1444 - val_accuracy: 0.9685
# Epoch 14/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0624 - accuracy: 0.9806 - val_loss: 0.1152 - val_accuracy: 0.9745
# Epoch 15/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.1364 - accuracy: 0.9629 - val_loss: 0.0848 - val_accuracy: 0.9760
# Epoch 16/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0592 - accuracy: 0.9780 - val_loss: 0.0370 - val_accuracy: 0.9940
# Epoch 17/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0304 - accuracy: 0.9906 - val_loss: 0.0366 - val_accuracy: 0.9910
# Epoch 18/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0171 - accuracy: 0.9937 - val_loss: 0.0661 - val_accuracy: 0.9865
# Epoch 19/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0196 - accuracy: 0.9937 - val_loss: 0.0572 - val_accuracy: 0.9910
# Epoch 20/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0380 - accuracy: 0.9899 - val_loss: 0.0633 - val_accuracy: 0.9940
# Epoch 21/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0428 - accuracy: 0.9900 - val_loss: 0.0529 - val_accuracy: 0.9910
# Epoch 22/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0187 - accuracy: 0.9950 - val_loss: 0.0702 - val_accuracy: 0.9880
# Epoch 23/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0316 - accuracy: 0.9906 - val_loss: 0.0762 - val_accuracy: 0.9895
# Epoch 24/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0757 - accuracy: 0.9805 - val_loss: 0.0378 - val_accuracy: 0.9895
# Epoch 25/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0182 - accuracy: 0.9956 - val_loss: 0.0231 - val_accuracy: 0.9940
# Epoch 26/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0083 - accuracy: 0.9975 - val_loss: 0.0234 - val_accuracy: 0.9955
# Epoch 27/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0214 - val_accuracy: 0.9955
# Epoch 28/40
# 50/50 [==============================] - 3s 58ms/step - loss: 0.0055 - accuracy: 0.9969 - val_loss: 0.1251 - val_accuracy: 0.9865
# Epoch 29/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0253 - accuracy: 0.9931 - val_loss: 0.2369 - val_accuracy: 0.9550
# Epoch 30/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.1493 - accuracy: 0.9635 - val_loss: 0.0340 - val_accuracy: 0.9940
# Epoch 31/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0611 - accuracy: 0.9819 - val_loss: 0.0841 - val_accuracy: 0.9865
# Epoch 32/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0393 - accuracy: 0.9862 - val_loss: 0.0678 - val_accuracy: 0.9925
# Epoch 33/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0201 - accuracy: 0.9931 - val_loss: 0.0815 - val_accuracy: 0.9925
# Epoch 34/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0258 - accuracy: 0.9937 - val_loss: 0.0853 - val_accuracy: 0.9850
# Epoch 35/40
# 50/50 [==============================] - 3s 58ms/step - loss: 0.0469 - accuracy: 0.9862 - val_loss: 0.0788 - val_accuracy: 0.9895
# Epoch 36/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0575 - accuracy: 0.9856 - val_loss: 0.0540 - val_accuracy: 0.9940
# Epoch 37/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0088 - accuracy: 0.9981 - val_loss: 0.0743 - val_accuracy: 0.9940
# Epoch 38/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0181 - accuracy: 0.9943 - val_loss: 0.1277 - val_accuracy: 0.9730
# Epoch 39/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0228 - accuracy: 0.9937 - val_loss: 0.0550 - val_accuracy: 0.9925
# Epoch 40/40
# 50/50 [==============================] - 3s 57ms/step - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.0613 - val_accuracy: 0.9940
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Test loss: 2.802186281954656
# Test accuracy: 0.66030926
# hello this is the end ***
