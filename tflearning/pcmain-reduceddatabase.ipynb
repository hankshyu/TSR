# %%
# this is the classic cnn model with reduced database

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import tensorflow as tf
from stn import spatial_transformer_network as transformer
import tensorflow.keras.activations as ac
import numpy as np
import matplotlib.pyplot as plt
import os
#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import cv2

# %%
train = ImageDataGenerator(rescale=1 / 255,validation_split=0.2)
test = ImageDataGenerator(rescale=1 / 255)

# %%
image_size=(150,150)

# %%
train_dataset = train.flow_from_directory("../database/sharpness1reduce/train",
                                          target_size=image_size,
                                          class_mode="categorical",
                                          subset="training",
                                          
                                         )
valid_dataset = train.flow_from_directory("../database/sharpness1reduce/train",
                                          target_size=image_size,
                                          class_mode="categorical",                                          
                                          subset="validation")

test_dataset = test.flow_from_directory("../database/sharpness1reduce/test",
                                        target_size=image_size,                                       
                                        class_mode="categorical")
# Out:
# Found 3282 images belonging to 49 classes.
# Found 795 images belonging to 49 classes.
# Found 1919 images belonging to 49 classes.

# %%
model = tf.keras.models.Sequential(
    [
        tf.keras.Input(shape=(150, 150, 3)),
        
        tf.keras.layers.Conv2D(32, kernel_size=(7, 7),padding="same",activation="relu"),
        tf.keras.layers.Conv2D(64, kernel_size=(3, 3),padding="same",activation="relu"),
        tf.keras.layers.Dropout(0.1),
        tf.keras.layers.MaxPooling2D(pool_size=(2 ,2)),
        
        tf.keras.layers.Conv2D(32, kernel_size=(5, 5), padding="same",activation="relu"),
        tf.keras.layers.Conv2D(64, kernel_size=(3, 3),padding="same",activation="relu"),
        tf.keras.layers.Dropout(0.1),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),

        
        tf.keras.layers.Conv2D(32, kernel_size=(3, 3),padding="same",activation="relu"),        
        tf.keras.layers.Conv2D(64, kernel_size=(3, 3),padding="same",activation="relu"),
        tf.keras.layers.Dropout(0.1),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
      

        tf.keras.layers.Flatten(),

        tf.keras.layers.Dense(512),
        tf.keras.layers.ReLU(),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
        
        tf.keras.layers.Dense(256),
        tf.keras.layers.ReLU(),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
        
        tf.keras.layers.Dense(128),
        tf.keras.layers.ReLU(),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
        
        tf.keras.layers.Dense(128),
        tf.keras.layers.ReLU(),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
        
        tf.keras.layers.Dense(49, activation="softmax")
    ]
)
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_42 (Conv2D)           (None, 150, 150, 32)      4736
# _________________________________________________________________
# conv2d_43 (Conv2D)           (None, 150, 150, 64)      18496
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 150, 150, 64)      0
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_44 (Conv2D)           (None, 75, 75, 32)        51232
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 75, 75, 64)        18496
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 75, 75, 64)        0
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 37, 37, 32)        18464
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 37, 37, 64)        18496
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 37, 37, 64)        0
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 18, 18, 64)        0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 20736)             0
# _________________________________________________________________
# dense_29 (Dense)             (None, 512)               10617344
# _________________________________________________________________
# re_lu_23 (ReLU)              (None, 512)               0
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 256)               131328
# _________________________________________________________________
# re_lu_24 (ReLU)              (None, 256)               0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_31 (Dense)             (None, 128)               32896
# _________________________________________________________________
# re_lu_25 (ReLU)              (None, 128)               0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 128)               16512
# _________________________________________________________________
# re_lu_26 (ReLU)              (None, 128)               0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_33 (Dense)             (None, 49)                6321
# =================================================================
# Total params: 10,938,417
# Trainable params: 10,936,369
# Non-trainable params: 2,048
# _________________________________________________________________

# %%
model.compile(loss="categorical_crossentropy", optimizer="sgd", metrics=["accuracy"])

model.fit(train_dataset, steps_per_epoch=50,validation_data=valid_dataset, epochs=100,shuffle=True)

score = model.evaluate(test_dataset, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
print("hello this is the end ***")
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 50 steps, validate for 25 steps
# Epoch 1/100
# 50/50 [==============================] - 5s 98ms/step - loss: 3.6119 - accuracy: 0.1305 - val_loss: 3.5584 - val_accuracy: 0.1648
# Epoch 2/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.6314 - accuracy: 0.1213 - val_loss: 3.6761 - val_accuracy: 0.1145
# Epoch 3/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.5792 - accuracy: 0.1331 - val_loss: 3.9122 - val_accuracy: 0.0553
# Epoch 4/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.5725 - accuracy: 0.1306 - val_loss: 3.6546 - val_accuracy: 0.0906
# Epoch 5/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.5674 - accuracy: 0.1513 - val_loss: 3.8613 - val_accuracy: 0.0440
# Epoch 6/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.5168 - accuracy: 0.1412 - val_loss: 3.7977 - val_accuracy: 0.0491
# Epoch 7/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.5228 - accuracy: 0.1419 - val_loss: 3.9406 - val_accuracy: 0.0302
# Epoch 8/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.4994 - accuracy: 0.1513 - val_loss: 3.6535 - val_accuracy: 0.0767
# Epoch 9/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.5108 - accuracy: 0.1531 - val_loss: 3.6768 - val_accuracy: 0.0780
# Epoch 10/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.4892 - accuracy: 0.1501 - val_loss: 3.7824 - val_accuracy: 0.0302
# Epoch 11/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.4645 - accuracy: 0.1627 - val_loss: 3.7690 - val_accuracy: 0.0302
# Epoch 12/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.4624 - accuracy: 0.1544 - val_loss: 3.5935 - val_accuracy: 0.1132
# Epoch 13/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.4606 - accuracy: 0.1556 - val_loss: 3.5194 - val_accuracy: 0.1296
# Epoch 14/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.4667 - accuracy: 0.1538 - val_loss: 3.5239 - val_accuracy: 0.1296
# Epoch 15/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.4319 - accuracy: 0.1481 - val_loss: 3.4276 - val_accuracy: 0.2050
# Epoch 16/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.4228 - accuracy: 0.1646 - val_loss: 3.9744 - val_accuracy: 0.0277
# Epoch 17/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.4048 - accuracy: 0.1747 - val_loss: 3.8125 - val_accuracy: 0.0302
# Epoch 18/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.4107 - accuracy: 0.1646 - val_loss: 3.6147 - val_accuracy: 0.0969
# Epoch 19/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.3901 - accuracy: 0.1646 - val_loss: 3.3581 - val_accuracy: 0.2390
# Epoch 20/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.3826 - accuracy: 0.1627 - val_loss: 3.7634 - val_accuracy: 0.0352
# Epoch 21/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.3712 - accuracy: 0.1656 - val_loss: 3.4992 - val_accuracy: 0.1396
# Epoch 22/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.3712 - accuracy: 0.1725 - val_loss: 3.7656 - val_accuracy: 0.0377
# Epoch 23/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.3631 - accuracy: 0.1587 - val_loss: 3.3730 - val_accuracy: 0.1736
# Epoch 24/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.3535 - accuracy: 0.1675 - val_loss: 3.3872 - val_accuracy: 0.1585
# Epoch 25/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.3487 - accuracy: 0.1750 - val_loss: 3.3597 - val_accuracy: 0.1987
# Epoch 26/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.3271 - accuracy: 0.1713 - val_loss: 3.7235 - val_accuracy: 0.0528
# Epoch 27/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.3233 - accuracy: 0.1532 - val_loss: 3.4949 - val_accuracy: 0.1270
# Epoch 28/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.3213 - accuracy: 0.1787 - val_loss: 3.7462 - val_accuracy: 0.0566
# Epoch 29/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.3112 - accuracy: 0.1694 - val_loss: 3.5939 - val_accuracy: 0.0981
# Epoch 30/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.3152 - accuracy: 0.1595 - val_loss: 3.6707 - val_accuracy: 0.0755
# Epoch 31/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.3134 - accuracy: 0.1797 - val_loss: 3.4762 - val_accuracy: 0.1409
# Epoch 32/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.2943 - accuracy: 0.1700 - val_loss: 3.4829 - val_accuracy: 0.1296
# Epoch 33/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.2745 - accuracy: 0.1988 - val_loss: 3.5572 - val_accuracy: 0.1057
# Epoch 34/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.2761 - accuracy: 0.1683 - val_loss: 3.5573 - val_accuracy: 0.0981
# Epoch 35/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.2684 - accuracy: 0.1700 - val_loss: 3.7035 - val_accuracy: 0.0767
# Epoch 36/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.2583 - accuracy: 0.1646 - val_loss: 3.4440 - val_accuracy: 0.1384
# Epoch 37/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.2707 - accuracy: 0.1810 - val_loss: 3.6335 - val_accuracy: 0.0855
# Epoch 38/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.2357 - accuracy: 0.1690 - val_loss: 3.8410 - val_accuracy: 0.0553
# Epoch 39/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.2453 - accuracy: 0.1734 - val_loss: 3.8053 - val_accuracy: 0.0755
# Epoch 40/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.2409 - accuracy: 0.1769 - val_loss: 3.1953 - val_accuracy: 0.2340
# Epoch 41/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.2331 - accuracy: 0.1681 - val_loss: 3.5328 - val_accuracy: 0.1157
# Epoch 42/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.2175 - accuracy: 0.1956 - val_loss: 3.7368 - val_accuracy: 0.0805
# Epoch 43/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.2227 - accuracy: 0.1721 - val_loss: 3.9308 - val_accuracy: 0.0692
# Epoch 44/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.2363 - accuracy: 0.1731 - val_loss: 4.1032 - val_accuracy: 0.0314
# Epoch 45/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.2063 - accuracy: 0.1731 - val_loss: 3.5173 - val_accuracy: 0.1220
# Epoch 46/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.1958 - accuracy: 0.1753 - val_loss: 3.3932 - val_accuracy: 0.1296
# Epoch 47/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.1881 - accuracy: 0.1650 - val_loss: 3.1987 - val_accuracy: 0.2289
# Epoch 48/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.1871 - accuracy: 0.2050 - val_loss: 3.6102 - val_accuracy: 0.0994
# Epoch 49/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.1760 - accuracy: 0.1750 - val_loss: 3.5037 - val_accuracy: 0.1107
# Epoch 50/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.1706 - accuracy: 0.1690 - val_loss: 3.1948 - val_accuracy: 0.2164
# Epoch 51/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.1440 - accuracy: 0.1794 - val_loss: 3.0418 - val_accuracy: 0.2843
# Epoch 52/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.1735 - accuracy: 0.1806 - val_loss: 3.4579 - val_accuracy: 0.1031
# Epoch 53/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.1508 - accuracy: 0.1800 - val_loss: 3.6876 - val_accuracy: 0.1019
# Epoch 54/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.1610 - accuracy: 0.1702 - val_loss: 3.5416 - val_accuracy: 0.1044
# Epoch 55/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.1406 - accuracy: 0.2006 - val_loss: 4.1377 - val_accuracy: 0.0591
# Epoch 56/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.1454 - accuracy: 0.1794 - val_loss: 4.0734 - val_accuracy: 0.0805
# Epoch 57/100
# 50/50 [==============================] - 4s 75ms/step - loss: 3.1263 - accuracy: 0.1936 - val_loss: 3.1809 - val_accuracy: 0.1786
# Epoch 58/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.1299 - accuracy: 0.1669 - val_loss: 3.4009 - val_accuracy: 0.1245
# Epoch 59/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.1288 - accuracy: 0.1819 - val_loss: 3.3648 - val_accuracy: 0.1371
# Epoch 60/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.1069 - accuracy: 0.1737 - val_loss: 3.0248 - val_accuracy: 0.2277
# Epoch 61/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.1162 - accuracy: 0.1994 - val_loss: 4.2306 - val_accuracy: 0.0755
# Epoch 62/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.0993 - accuracy: 0.1787 - val_loss: 3.1758 - val_accuracy: 0.1384
# Epoch 63/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.1002 - accuracy: 0.2006 - val_loss: 2.9873 - val_accuracy: 0.2717
# Epoch 64/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.0919 - accuracy: 0.1765 - val_loss: 2.9661 - val_accuracy: 0.3145
# Epoch 65/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.0601 - accuracy: 0.2025 - val_loss: 3.2512 - val_accuracy: 0.1560
# Epoch 66/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.0678 - accuracy: 0.1885 - val_loss: 3.2340 - val_accuracy: 0.1170
# Epoch 67/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.0495 - accuracy: 0.2019 - val_loss: 3.3310 - val_accuracy: 0.1245
# Epoch 68/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.0718 - accuracy: 0.1906 - val_loss: 3.3212 - val_accuracy: 0.1119
# Epoch 69/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.0706 - accuracy: 0.1800 - val_loss: 2.9390 - val_accuracy: 0.2415
# Epoch 70/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.0667 - accuracy: 0.1844 - val_loss: 3.1768 - val_accuracy: 0.1522
# Epoch 71/100
# 50/50 [==============================] - 4s 75ms/step - loss: 3.0590 - accuracy: 0.1929 - val_loss: 3.6290 - val_accuracy: 0.1019
# Epoch 72/100
# 50/50 [==============================] - 4s 75ms/step - loss: 3.0457 - accuracy: 0.1961 - val_loss: 4.2551 - val_accuracy: 0.0792
# Epoch 73/100
# 50/50 [==============================] - 4s 77ms/step - loss: 3.0489 - accuracy: 0.1863 - val_loss: 2.9873 - val_accuracy: 0.2113
# Epoch 74/100
# 50/50 [==============================] - 4s 75ms/step - loss: 3.0411 - accuracy: 0.1885 - val_loss: 2.9255 - val_accuracy: 0.2176
# Epoch 75/100
# 50/50 [==============================] - 4s 75ms/step - loss: 3.0214 - accuracy: 0.1866 - val_loss: 3.3509 - val_accuracy: 0.1082
# Epoch 76/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.0361 - accuracy: 0.1944 - val_loss: 3.3137 - val_accuracy: 0.1145
# Epoch 77/100
# 50/50 [==============================] - 4s 75ms/step - loss: 3.0065 - accuracy: 0.1803 - val_loss: 3.0343 - val_accuracy: 0.1623
# Epoch 78/100
# 50/50 [==============================] - 4s 76ms/step - loss: 3.0078 - accuracy: 0.1881 - val_loss: 3.9632 - val_accuracy: 0.0931
# Epoch 79/100
# 50/50 [==============================] - 4s 76ms/step - loss: 2.9925 - accuracy: 0.1838 - val_loss: 3.0836 - val_accuracy: 0.1459
# Epoch 80/100
# 50/50 [==============================] - 4s 76ms/step - loss: 2.9724 - accuracy: 0.1994 - val_loss: 3.6590 - val_accuracy: 0.0994
# Epoch 81/100
# 50/50 [==============================] - 4s 76ms/step - loss: 2.9737 - accuracy: 0.1969 - val_loss: 3.8457 - val_accuracy: 0.0981
# Epoch 82/100
# 50/50 [==============================] - 4s 76ms/step - loss: 2.9636 - accuracy: 0.1863 - val_loss: 3.5351 - val_accuracy: 0.1019
# Epoch 83/100
# 50/50 [==============================] - 4s 76ms/step - loss: 2.9712 - accuracy: 0.1919 - val_loss: 3.6244 - val_accuracy: 0.0969
# Epoch 84/100
# 50/50 [==============================] - 4s 75ms/step - loss: 2.9710 - accuracy: 0.1892 - val_loss: 3.2802 - val_accuracy: 0.1107
# Epoch 85/100
# 50/50 [==============================] - 4s 75ms/step - loss: 2.9722 - accuracy: 0.1986 - val_loss: 3.2447 - val_accuracy: 0.1119
# Epoch 86/100
# 50/50 [==============================] - 4s 76ms/step - loss: 2.9534 - accuracy: 0.1847 - val_loss: 3.5696 - val_accuracy: 0.1006
# Epoch 87/100
# 50/50 [==============================] - 4s 76ms/step - loss: 2.9198 - accuracy: 0.1937 - val_loss: 3.5239 - val_accuracy: 0.1019
# Epoch 88/100
# 50/50 [==============================] - 4s 76ms/step - loss: 2.9147 - accuracy: 0.2081 - val_loss: 3.7178 - val_accuracy: 0.0994
# Epoch 89/100
# 50/50 [==============================] - 4s 75ms/step - loss: 2.9150 - accuracy: 0.2125 - val_loss: 3.1358 - val_accuracy: 0.1245
# Epoch 90/100
# 50/50 [==============================] - 4s 76ms/step - loss: 2.9233 - accuracy: 0.2013 - val_loss: 3.2925 - val_accuracy: 0.1132
# Epoch 91/100
# 50/50 [==============================] - 4s 75ms/step - loss: 2.9053 - accuracy: 0.1784 - val_loss: 3.3337 - val_accuracy: 0.1069
# Epoch 92/100
# 50/50 [==============================] - 4s 76ms/step - loss: 2.8819 - accuracy: 0.1904 - val_loss: 3.6576 - val_accuracy: 0.1006
# Epoch 93/100
# 50/50 [==============================] - 4s 75ms/step - loss: 2.9033 - accuracy: 0.1948 - val_loss: 3.3516 - val_accuracy: 0.1208
# Epoch 94/100
# 50/50 [==============================] - 4s 75ms/step - loss: 2.8977 - accuracy: 0.1866 - val_loss: 3.1708 - val_accuracy: 0.1157
# Epoch 95/100
# 50/50 [==============================] - 4s 75ms/step - loss: 2.8683 - accuracy: 0.2112 - val_loss: 2.9093 - val_accuracy: 0.1623
# Epoch 96/100
# 50/50 [==============================] - 4s 76ms/step - loss: 2.8548 - accuracy: 0.2037 - val_loss: 3.7710 - val_accuracy: 0.1006
# Epoch 97/100
# 50/50 [==============================] - 4s 75ms/step - loss: 2.8707 - accuracy: 0.1841 - val_loss: 3.0001 - val_accuracy: 0.1472
# Epoch 98/100
# 50/50 [==============================] - 4s 76ms/step - loss: 2.8477 - accuracy: 0.2062 - val_loss: 3.0103 - val_accuracy: 0.1384
# Epoch 99/100
# 50/50 [==============================] - 4s 75ms/step - loss: 2.8296 - accuracy: 0.2011 - val_loss: 3.2648 - val_accuracy: 0.1119
# Epoch 100/100
# 50/50 [==============================] - 4s 76ms/step - loss: 2.8408 - accuracy: 0.1819 - val_loss: 3.5013 - val_accuracy: 0.1107
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Test loss: 3.931651182969411
# Test accuracy: 0.090672225
# hello this is the end ***
