# %%
# this is the classic cnn model with reduced database

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import tensorflow as tf
from stn import spatial_transformer_network as transformer
import tensorflow.keras.activations as ac
import numpy as np
import matplotlib.pyplot as plt
import os
#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import cv2

# %%
train = ImageDataGenerator(rescale=1 / 255,validation_split=0.2)
test = ImageDataGenerator(rescale=1 / 255)

# %%
image_size=(150,150)

# %%
train_dataset = train.flow_from_directory("../database/sharpness1reduce/train",
                                          target_size=image_size,
                                          class_mode="categorical",
                                          subset="training",
                                          
                                         )
valid_dataset = train.flow_from_directory("../database/sharpness1reduce/train",
                                          target_size=image_size,
                                          class_mode="categorical",                                          
                                          subset="validation")

test_dataset = test.flow_from_directory("../database/sharpness1reduce/test",
                                        target_size=image_size,                                       
                                        class_mode="categorical")
# Out:
# Found 3282 images belonging to 49 classes.
# Found 795 images belonging to 49 classes.
# Found 1919 images belonging to 49 classes.

# %%
model = tf.keras.models.Sequential(
    [
        tf.keras.Input(shape=(150, 150, 3)),
        
        tf.keras.layers.Conv2D(32, kernel_size=(7, 7),padding="same",activation="relu"),
        tf.keras.layers.Conv2D(64, kernel_size=(3, 3),activation="relu"),
        tf.keras.layers.Dropout(0.15),
        tf.keras.layers.MaxPooling2D(pool_size=(2 ,2)),
        
        tf.keras.layers.Conv2D(32, kernel_size=(5, 5), padding="same",activation="relu"),
        tf.keras.layers.Conv2D(64, kernel_size=(3, 3),activation="relu"),
        tf.keras.layers.Dropout(0.15),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        
        tf.keras.layers.Conv2D(32, kernel_size=(3, 3), padding="same",activation="relu"),
        tf.keras.layers.Conv2D(64, kernel_size=(3, 3),activation="relu"),
        tf.keras.layers.Dropout(0.15),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        
        tf.keras.layers.Conv2D(32, kernel_size=(3, 3),activation="relu"),        
        tf.keras.layers.Conv2D(64, kernel_size=(3, 3),activation="relu"),        
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
      

        tf.keras.layers.Flatten(),

        tf.keras.layers.Dense(256),
        tf.keras.layers.ReLU(),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
        
        tf.keras.layers.Dense(256),
        tf.keras.layers.ReLU(),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
        
        tf.keras.layers.Dense(128),
        tf.keras.layers.ReLU(),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.5),
        
        tf.keras.layers.Dense(49, activation="softmax")
    ]
)
model.summary()
# Out:
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_160 (Conv2D)          (None, 150, 150, 32)      4736
# _________________________________________________________________
# conv2d_161 (Conv2D)          (None, 148, 148, 64)      18496
# _________________________________________________________________
# dropout_88 (Dropout)         (None, 148, 148, 64)      0
# _________________________________________________________________
# max_pooling2d_80 (MaxPooling (None, 74, 74, 64)        0
# _________________________________________________________________
# conv2d_162 (Conv2D)          (None, 74, 74, 32)        51232
# _________________________________________________________________
# conv2d_163 (Conv2D)          (None, 72, 72, 64)        18496
# _________________________________________________________________
# dropout_89 (Dropout)         (None, 72, 72, 64)        0
# _________________________________________________________________
# max_pooling2d_81 (MaxPooling (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_164 (Conv2D)          (None, 36, 36, 32)        18464
# _________________________________________________________________
# conv2d_165 (Conv2D)          (None, 34, 34, 64)        18496
# _________________________________________________________________
# dropout_90 (Dropout)         (None, 34, 34, 64)        0
# _________________________________________________________________
# max_pooling2d_82 (MaxPooling (None, 17, 17, 64)        0
# _________________________________________________________________
# conv2d_166 (Conv2D)          (None, 15, 15, 32)        18464
# _________________________________________________________________
# conv2d_167 (Conv2D)          (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_83 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_26 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# dense_94 (Dense)             (None, 256)               590080
# _________________________________________________________________
# re_lu_45 (ReLU)              (None, 256)               0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_91 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_95 (Dense)             (None, 256)               65792
# _________________________________________________________________
# re_lu_46 (ReLU)              (None, 256)               0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_92 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_96 (Dense)             (None, 128)               32896
# _________________________________________________________________
# re_lu_47 (ReLU)              (None, 128)               0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_93 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_97 (Dense)             (None, 49)                6321
# =================================================================
# Total params: 864,529
# Trainable params: 863,249
# Non-trainable params: 1,280
# _________________________________________________________________

# %%
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(train_dataset, steps_per_epoch=50,validation_data=valid_dataset, epochs=50,shuffle=True)

score = model.evaluate(test_dataset, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
print("hello this is the end ***")
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 50 steps, validate for 25 steps
# Epoch 1/50
# 50/50 [==============================] - 5s 92ms/step - loss: 4.4293 - accuracy: 0.0825 - val_loss: 7.4391 - val_accuracy: 0.1119
# Epoch 2/50
# 50/50 [==============================] - 3s 68ms/step - loss: 3.4213 - accuracy: 0.2352 - val_loss: 6.0281 - val_accuracy: 0.0805
# Epoch 3/50
# 50/50 [==============================] - 3s 69ms/step - loss: 2.9353 - accuracy: 0.2862 - val_loss: 3.5391 - val_accuracy: 0.1497
# Epoch 4/50
# 50/50 [==============================] - 3s 69ms/step - loss: 2.5373 - accuracy: 0.3537 - val_loss: 3.5178 - val_accuracy: 0.2013
# Epoch 5/50
# 50/50 [==============================] - 4s 71ms/step - loss: 2.1942 - accuracy: 0.4325 - val_loss: 6.6402 - val_accuracy: 0.0805
# Epoch 6/50
# 50/50 [==============================] - 3s 67ms/step - loss: 1.8423 - accuracy: 0.5088 - val_loss: 4.4268 - val_accuracy: 0.1258
# Epoch 7/50
# 50/50 [==============================] - 3s 67ms/step - loss: 1.6277 - accuracy: 0.5517 - val_loss: 5.8957 - val_accuracy: 0.0805
# Epoch 8/50
# 50/50 [==============================] - 3s 67ms/step - loss: 1.4723 - accuracy: 0.6053 - val_loss: 2.2632 - val_accuracy: 0.3711
# Epoch 9/50
# 50/50 [==============================] - 3s 67ms/step - loss: 1.3868 - accuracy: 0.6160 - val_loss: 3.1603 - val_accuracy: 0.2906
# Epoch 10/50
# 50/50 [==============================] - 3s 67ms/step - loss: 1.1838 - accuracy: 0.6778 - val_loss: 2.1600 - val_accuracy: 0.3862
# Epoch 11/50
# 50/50 [==============================] - 3s 68ms/step - loss: 1.0922 - accuracy: 0.6963 - val_loss: 1.1423 - val_accuracy: 0.7031
# Epoch 12/50
# 50/50 [==============================] - 3s 67ms/step - loss: 1.0414 - accuracy: 0.7175 - val_loss: 1.5254 - val_accuracy: 0.5585
# Epoch 13/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.9752 - accuracy: 0.7306 - val_loss: 1.5915 - val_accuracy: 0.5698
# Epoch 14/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.8550 - accuracy: 0.7692 - val_loss: 2.1045 - val_accuracy: 0.4440
# Epoch 15/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.7611 - accuracy: 0.7976 - val_loss: 1.2091 - val_accuracy: 0.6629
# Epoch 16/50
# 50/50 [==============================] - 3s 68ms/step - loss: 0.7299 - accuracy: 0.7906 - val_loss: 0.7392 - val_accuracy: 0.8075
# Epoch 17/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.6735 - accuracy: 0.8178 - val_loss: 1.3438 - val_accuracy: 0.5975
# Epoch 18/50
# 50/50 [==============================] - 3s 68ms/step - loss: 0.6650 - accuracy: 0.8216 - val_loss: 0.5114 - val_accuracy: 0.8591
# Epoch 19/50
# 50/50 [==============================] - 3s 68ms/step - loss: 0.6338 - accuracy: 0.8342 - val_loss: 0.3915 - val_accuracy: 0.8994
# Epoch 20/50
# 50/50 [==============================] - 3s 68ms/step - loss: 0.5768 - accuracy: 0.8375 - val_loss: 0.3477 - val_accuracy: 0.9233
# Epoch 21/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.5201 - accuracy: 0.8487 - val_loss: 0.3496 - val_accuracy: 0.9119
# Epoch 22/50
# 50/50 [==============================] - 3s 68ms/step - loss: 0.5067 - accuracy: 0.8519 - val_loss: 0.3088 - val_accuracy: 0.9245
# Epoch 23/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.5009 - accuracy: 0.8613 - val_loss: 1.0003 - val_accuracy: 0.7094
# Epoch 24/50
# 50/50 [==============================] - 3s 68ms/step - loss: 0.4583 - accuracy: 0.8800 - val_loss: 0.2947 - val_accuracy: 0.9321
# Epoch 25/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.3851 - accuracy: 0.8972 - val_loss: 0.2311 - val_accuracy: 0.9484
# Epoch 26/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.3551 - accuracy: 0.9048 - val_loss: 1.2733 - val_accuracy: 0.6616
# Epoch 27/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.4035 - accuracy: 0.8913 - val_loss: 0.2269 - val_accuracy: 0.9484
# Epoch 28/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.2979 - accuracy: 0.9206 - val_loss: 0.2785 - val_accuracy: 0.9220
# Epoch 29/50
# 50/50 [==============================] - 3s 68ms/step - loss: 0.2733 - accuracy: 0.9300 - val_loss: 0.3125 - val_accuracy: 0.9145
# Epoch 30/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.2760 - accuracy: 0.9306 - val_loss: 0.4565 - val_accuracy: 0.8855
# Epoch 31/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.2558 - accuracy: 0.9250 - val_loss: 0.3483 - val_accuracy: 0.9119
# Epoch 32/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.2178 - accuracy: 0.9369 - val_loss: 0.3356 - val_accuracy: 0.9208
# Epoch 33/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.2177 - accuracy: 0.9450 - val_loss: 0.3583 - val_accuracy: 0.9082
# Epoch 34/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.2025 - accuracy: 0.9439 - val_loss: 0.1323 - val_accuracy: 0.9723
# Epoch 35/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.2057 - accuracy: 0.9464 - val_loss: 0.1955 - val_accuracy: 0.9535
# Epoch 36/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.1788 - accuracy: 0.9552 - val_loss: 0.1187 - val_accuracy: 0.9711
# Epoch 37/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.1733 - accuracy: 0.9533 - val_loss: 0.1204 - val_accuracy: 0.9648
# Epoch 38/50
# 50/50 [==============================] - 3s 68ms/step - loss: 0.1755 - accuracy: 0.9519 - val_loss: 0.0918 - val_accuracy: 0.9748
# Epoch 39/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.1674 - accuracy: 0.9533 - val_loss: 0.1758 - val_accuracy: 0.9560
# Epoch 40/50
# 50/50 [==============================] - 3s 68ms/step - loss: 0.1571 - accuracy: 0.9606 - val_loss: 0.1028 - val_accuracy: 0.9786
# Epoch 41/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.1363 - accuracy: 0.9622 - val_loss: 0.0970 - val_accuracy: 0.9799
# Epoch 42/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.1512 - accuracy: 0.9596 - val_loss: 0.0620 - val_accuracy: 0.9862
# Epoch 43/50
# 50/50 [==============================] - 3s 68ms/step - loss: 0.1333 - accuracy: 0.9606 - val_loss: 0.0829 - val_accuracy: 0.9786
# Epoch 44/50
# 50/50 [==============================] - 3s 68ms/step - loss: 0.1296 - accuracy: 0.9625 - val_loss: 0.0480 - val_accuracy: 0.9899
# Epoch 45/50
# 50/50 [==============================] - 3s 68ms/step - loss: 0.1381 - accuracy: 0.9613 - val_loss: 0.2366 - val_accuracy: 0.9371
# Epoch 46/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.1253 - accuracy: 0.9672 - val_loss: 0.1855 - val_accuracy: 0.9635
# Epoch 47/50
# 50/50 [==============================] - 3s 68ms/step - loss: 0.1504 - accuracy: 0.9581 - val_loss: 0.0853 - val_accuracy: 0.9774
# Epoch 48/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.1242 - accuracy: 0.9672 - val_loss: 0.1572 - val_accuracy: 0.9648
# Epoch 49/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.1160 - accuracy: 0.9691 - val_loss: 0.0800 - val_accuracy: 0.9786
# Epoch 50/50
# 50/50 [==============================] - 3s 67ms/step - loss: 0.1050 - accuracy: 0.9760 - val_loss: 0.3035 - val_accuracy: 0.9308
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Test loss: 2.3333641290664673
# Test accuracy: 0.5257947
# hello this is the end ***
